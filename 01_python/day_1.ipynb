# %%
marks = [34,36,38,39]
marks # learning phase - prodction --> .py
# Out:
# [34, 36, 38, 39]

# %%
marks.append(26)
marks
# Out:
# [34, 36, 38, 39, 26]

# %%
# [] == for list
# () for tuple

# use case ?

# %%
marks = (34,36,38,39,56,89)
marks
# Out:
# (34, 36, 38, 39, 56, 89)

# %%
marks[6]=56
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 marks[6]=56
#
# TypeError: 'tuple' object does not support item assignment
